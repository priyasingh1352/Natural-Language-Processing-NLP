# %% [markdown]
# # Stop Word

# %%
var = "To improve your data analysis skills, consider the following approaches:Develop a Strong Foundation: Master fundamental skills such as statistics, data visualization, and programming languages like Python and R.1Opt for Educational Programs: Pursue a degree, course, or bootcamp in data analytics to gain structured learning experiences."

# %%
var
# Out:
# 'To improve your data analysis skills, consider the following approaches:Develop a Strong Foundation: Master fundamental skills such as statistics, data visualization, and programming languages like Python and R.1Opt for Educational Programs: Pursue a degree, course, or bootcamp in data analytics to gain structured learning experiences.'

# %%
import nltk

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Priya
# [nltk_data]     singh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
from string import punctuation

# %%
stop_word = stopwords.words("english")

# %%
stopwords
# Out:
# <WordListCorpusReader in 'C:\\Users\\Priya singh\\AppData\\Roaming\\nltk_data\\corpora\\stopwords'>

# %%
print(stop_word[:20])
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been']
