# %% [markdown]
# # Lemmatization

# %%
# Technique just like stemming , the output we will get after lemmatization is called lemma.It corrects the word and done stemming both.We get the valid word which means the same.

# %%
from nltk.stem import WordNetLemmatizer

# %%
import nltk

# %%
wnl = WordNetLemmatizer()

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Priya
# [nltk_data]     singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
wnl.lemmatize("mice")
# Out:
# 'mouse'
